# %% [markdown]
# ## Extraer tablas de la seccion 1

# %% [markdown]
# Se importan las librerías generales que se utilizarían, además de los documentos CSV creados en el paso anterior

# %%
import pandas as pd
import numpy as np

#Csv importaciones
df_Segment = pd.read_csv("df_Segment.csv", index_col=0)
df_Category = pd.read_csv("df_Category.csv", index_col=0)
df_Product_N = pd.read_csv("df_Product.csv", index_col=0)
df_Sales_N = pd.read_csv("df_Sales.csv", index_col=0)
df_Calendar = pd.read_csv("df_Calendar.csv", index_col=0)

# %% [markdown]
# ## Preparación de tablas a utilizar

# %% [markdown]
# Se remueve atributos duplicados para las tablas DUMMIES

# %%
def list_duplicates(seq):
  seen = set()
  seen_add = seen.add
  # adds all elements it doesn't know yet to seen and all other to seen_twice
  seen_twice = set( x for x in seq if x in seen or seen_add(x) )
  # turn the set into a list (as requested)
  return list( seen_twice )

# %%
Lista = [*df_Product_N["ATTR3"].unique(), *df_Product_N["ATTR2"].unique(), *df_Product_N["ATTR1"].unique()]
#print(Lista)

print("\nColumnas duplicadas: ", list_duplicates(Lista))
# Out:
# Columnas duplicadas:  [nan, 'SANITIZANTE', 'CLORO']

# %% [markdown]
# ### Creación de tabla de DUMMIES para atributos booleanos.

# %%
# Crear tabla de DUMMIES
Dummies_Etiquetas = pd.get_dummies(df_Product_N[["ATTR3","ATTR2", "ATTR1"]]) 

## Combinar True para misma etiqueta
Dummies_Etiquetas["ATTR1_CLORO"] = Dummies_Etiquetas["ATTR1_CLORO"] | Dummies_Etiquetas["ATTR2_CLORO"] 
Dummies_Etiquetas["ATTR1_SANITIZANTE"] = Dummies_Etiquetas["ATTR1_SANITIZANTE"] | Dummies_Etiquetas["ATTR2_SANITIZANTE"]

# Remover columnas ya no se utilizaran
Dummies_Etiquetas.drop(columns= ["ATTR2_CLORO","ATTR2_SANITIZANTE"], inplace=True) 

# Remover el prefijo ATTR?
Dummies_Etiquetas.columns = Dummies_Etiquetas.columns.str[6:]

# Ordenar columnas en orden alfabetico
Dummies_Etiquetas = Dummies_Etiquetas.sort_index(axis=1)

Dummies_Etiquetas
# Out:
#      BAMBINO  BLANCO  CLORO  COLOR PODER VINAGRE  FABRIC TREATMENT  GERMICIDA  \
# 0      False   False   True                False             False      False
# 1      False   False   True                False             False      False
# 2      False   False   True                False             False      False
# 3      False   False   True                False             False      False
# 4      False   False   True                False             False      False
# ..       ...     ...    ...                  ...               ...        ...
# 498    False   False  False                False              True      False
# 499    False   False   True                False             False      False
# 500    False   False  False                False              True      False
# 501    False   False   True                False             False      False
# 502    False   False   True                False             False      False
#
#      MASCOTAS  MULTIUSOS  NO DEFINIDO  OTR. TIPOS  PRE LAVADOR  PRELAVADOR  \
# 0       False      False         True       False        False       False
# 1       False      False         True       False        False       False
# 2       False      False         True       False        False       False
# 3       False      False         True       False        False       False
# 4       False      False         True       False        False       False
# ..        ...        ...          ...         ...          ...         ...
# 498     False      False        False       False         True       False
# 499      True      False        False       False        False       False
# 500     False      False        False       False        False       False
# 501     False      False         True       False        False       False
# 502     False      False         True       False        False       False
#
#      QUITAMANCHAS  ROPA BEBE  ROPA BLANCA  ROPA COLOR   ROSA  SAFE BLEACH  \
# 0           False      False        False       False  False        False
# 1           False      False        False       False  False        False
# 2           False      False        False       False  False        False
# 3           False      False        False       False  False        False
# 4           False      False        False       False  False        False
# ..            ...        ...          ...         ...    ...          ...
# 498         False      False        False       False  False         True
# 499         False      False        False       False  False        False
# 500         False      False        False       False   True         True
# 501         False      False        False       False  False        False
# 502         False      False        False       False  False        False
#
#      SANITIZANTE  SANITIZANTE
# 0          False        False
# 1          False        False
# 2          False        False
# 3          False        False
# 4          False        False
# ..           ...          ...
# 498        False        False
# 499        False        False
# 500        False        False
# 501        False        False
# 502        False        False
#
# [503 rows x 20 columns]

# %% [markdown]
# ### Remover los atributos para combinar las tablas posteriormente

# %%
df_Product_N.loc[0:, ~df_Product_N.columns.isin(["ATTR1","ATTR2", "ATTR3"])]
# Out:
#            MANUFACTURER      BRAND              ITEM  \
# 0            INDS. ALEN   CLORALEX     0000075000592
# 1            INDS. ALEN   CLORALEX     0000075000608
# 2            INDS. ALEN   CLORALEX     0000075000615
# 3            INDS. ALEN   CLORALEX     0000075000622
# 4            INDS. ALEN   CLORALEX     0000075000639
# ..                  ...        ...               ...
# 498              IBERIA     IBERIA     8411660210036
# 499  JABONERA LA ESPUMA  BCLORHADA  7501681101305BP1
# 500             RECKITT     VANISH  7501058789778BP1
# 501          INDS. ALEN   CLORALEX     7501025412142
# 502              CLOROX     CLOROX  7502240948188BP1
#
#                                       ITEM_DESCRIPTION  CATEGORY   FORMAT
# 0    CLORALEX EL RENDIDOR BOT.PLAST. 250ML NAL. 000...         1  LIQUIDO
# 1    CLORALEX EL RENDIDOR BOT.PLAST. 500ML NAL. 000...         1  LIQUIDO
# 2    CLORALEX EL RENDIDOR BOT.PLAST. 950ML NAL. 000...         1  LIQUIDO
# 3    CLORALEX EL RENDIDOR BOT.PLAST. 2000ML NAL 000...         1  LIQUIDO
# 4    CLORALEX EL RENDIDOR BOT.PLAST. 3750ML NAL 000...         1  LIQUIDO
# ..                                                 ...       ...      ...
# 498  IBERIA REVOLUTION QUITA MANCHAS ACCIDENTALES B...         1  LIQUIDO
# 499  BCLORHADA MASC DET DES C/CLOR1L+MM MASCHOGAR D...         1  LIQUIDO
# 500  VANISH EXT HIGIENE REM MANCHAS GAL 4LT + VANIS...         1  LIQUIDO
# 501  CLORALEX AROMAS BLANQUEADOR C/AROMA LAVANDA GA...         1  LIQUIDO
# 502  CLOROX BLANQ930M+MMBLANQINOD709M+MMFIBRAULTRA1...         1  LIQUIDO
#
# [503 rows x 6 columns]

# %% [markdown]
# ## Uso del Market Basket para analizar las combinaciones de Atributos mas comunes en los productos

# %%
# instalación del módulo mlxtend --- Por si no lo tenian instalado
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\gamer\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\gamer\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gamer\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gamer\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gamer\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gamer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\gamer\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %%
# Aplicación del algoritmo "a priori" para localizar los articulos frecuentemente comprados en la base de datos
from mlxtend.frequent_patterns import apriori

# Analisis "a priori" con un soporte minimo del 1.5%
articulos_frec = apriori(Dummies_Etiquetas, min_support= 0.2, use_colnames= True)
articulos_frec = articulos_frec.sort_values("support", ascending= False)
articulos_frec = articulos_frec.reset_index(drop = True)

# articulos_frec["length"] = articulos_frec["itemsets"].apply(lambda x: len(x))
articulos_frec
# Out:
#     support                         itemsets
# 0  0.491054                          (CLORO)
# 1  0.487078               (FABRIC TREATMENT)
# 2  0.433400                    (SAFE BLEACH)
# 3  0.433400  (FABRIC TREATMENT, SAFE BLEACH)
# 4  0.270378                    (NO DEFINIDO)
# 5  0.270378             (NO DEFINIDO, CLORO)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(articulos_frec, metric = "confidence",
                 min_threshold = 0.6).sort_values("confidence", ascending = False).reset_index(drop = True)
# Out:
#           antecedents         consequents  antecedent support  \
# 0       (SAFE BLEACH)  (FABRIC TREATMENT)            0.433400
# 1       (NO DEFINIDO)             (CLORO)            0.270378
# 2  (FABRIC TREATMENT)       (SAFE BLEACH)            0.487078
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.487078  0.433400    1.000000  2.053061               1.0
# 1            0.491054  0.270378    1.000000  2.036437               1.0
# 2            0.433400  0.433400    0.889796  2.053061               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.222300         inf       0.905263  0.889796   1.000000    0.944898
# 1  0.137608         inf       0.697548  0.550607   1.000000    0.775304
# 2  0.222300    5.141374       1.000000  0.889796   0.805499    0.944898

# %% [markdown]
# ### Al revisar esto la "Combinacion" mas comun de etiquetas, por lo menos las mas utilizadas, son excluyentes entre ellas, por lo cual se analizara si hay algun tipo de relacion entre el inclemente de una categoria con respecto a la otra, ademas de intentar predecir los comportamientos que presentaran.

# %% [markdown]
# ## Se combinan las tablas de Sales, Calendar, Dummies_Atributo y Calendario para posteriores usos.

# %%
Dummies_Etiquetas["ITEM"] = df_Product_N["ITEM"]

#Tabla con producto y atributo
Items_ATTR_CF = Dummies_Etiquetas.loc[:,["ITEM","CLORO", "FABRIC TREATMENT"]]

# Combinacion de tablas para tener las fechas y etiqueta atributo
df_Sales_on_time = pd.merge(df_Sales_N, df_Calendar, on='WEEK', how='inner')
df_Sales_on_time.rename(columns={'ITEM_CODE': 'ITEM'}, inplace= True)

Sales_Time_ATTR = pd.merge(df_Sales_on_time, Items_ATTR_CF, on='ITEM', how='inner')

Sales_Time_ATTR.head(5)
# Out:
#     WEEK              ITEM  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0  34-22  7501058792808BP2             0.006              0.139
# 1  34-22     7501058715883             0.487            116.519
# 2  34-22     7702626213774             1.391             68.453
# 3  34-22     7501058716422             0.022              1.481
# 4  34-22     7501058784353             2.037            182.839
#
#    TOTAL_UNIT_AVG_WEEKLY_SALES              REGION  YEAR  MONTH  WEEK_NUMBER  \
# 0                        1.000  TOTAL AUTOS AREA 5  2022      8           34
# 1                        2.916  TOTAL AUTOS AREA 5  2022      8           34
# 2                        5.171  TOTAL AUTOS AREA 5  2022      8           34
# 3                        1.833  TOTAL AUTOS AREA 5  2022      8           34
# 4                        5.375  TOTAL AUTOS AREA 5  2022      8           34
#
#          DATE  CLORO  FABRIC TREATMENT
# 0  2022-08-28  False              True
# 1  2022-08-28  False              True
# 2  2022-08-28  False              True
# 3  2022-08-28  False              True
# 4  2022-08-28  False              True

# %%
Dummies_Etiquetas["ITEM"] = df_Product_N["ITEM"]

#Tabla con producto y atributo
Items_ATTR_CF = Dummies_Etiquetas.loc[:,["ITEM","CLORO", "FABRIC TREATMENT"]]

# Combinacion de tablas para tener las fechas y etiqueta atributo
df_Sales_on_time = pd.merge(df_Sales_N, df_Calendar, on='WEEK', how='inner')
df_Sales_on_time.rename(columns={'ITEM_CODE': 'ITEM'}, inplace= True)

Sales_Time_ATTR = pd.merge(df_Sales_on_time, Items_ATTR_CF, on='ITEM', how='inner')

Sales_Time_ATTR.head(5)
# Out:
#     WEEK              ITEM  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# 0  34-22  7501058792808BP2             0.006              0.139
# 1  34-22     7501058715883             0.487            116.519
# 2  34-22     7702626213774             1.391             68.453
# 3  34-22     7501058716422             0.022              1.481
# 4  34-22     7501058784353             2.037            182.839
#
#    TOTAL_UNIT_AVG_WEEKLY_SALES              REGION  YEAR  MONTH  WEEK_NUMBER  \
# 0                        1.000  TOTAL AUTOS AREA 5  2022      8           34
# 1                        2.916  TOTAL AUTOS AREA 5  2022      8           34
# 2                        5.171  TOTAL AUTOS AREA 5  2022      8           34
# 3                        1.833  TOTAL AUTOS AREA 5  2022      8           34
# 4                        5.375  TOTAL AUTOS AREA 5  2022      8           34
#
#          DATE  CLORO  FABRIC TREATMENT
# 0  2022-08-28  False              True
# 1  2022-08-28  False              True
# 2  2022-08-28  False              True
# 3  2022-08-28  False              True
# 4  2022-08-28  False              True

# %%
Sales_Time_ATTR.to_csv('Sales_Time_ATTR.csv', index=False)
